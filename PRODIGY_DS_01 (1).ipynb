# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\jeme0\Downloads\Task01_Age_Distribution_500Rows.xlsx")

# %%
df.head()
# Out:
#    ID  Age
# 0   1   58
# 1   2   25
# 2   3   19
# 3   4   35
# 4   5   33

# %%
df.shape
# Out:
# (500, 2)

# %%
df.isnull().sum()
# Out:
# ID     0
# Age    0
# dtype: int64

# %%
df.describe()
# Out:
#                ID         Age
# count  500.000000  500.000000
# mean   250.500000   38.450000
# std    144.481833   12.654318
# min      1.000000   18.000000
# 25%    125.750000   27.750000
# 50%    250.500000   37.000000
# 75%    375.250000   50.000000
# max    500.000000   60.000000

# %%
plt.figure(figsize=(10,6))
plt.hist(df['Age'], bins=10)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.hist(df['Age'], bins=15)
plt.title('Distribution of Age in Population Dataset')
plt.xlabel('Age')
plt.ylabel('Number of People')
plt.grid(True)
plt.savefig('Task01_Age_Distribution.png')
plt.show()

# %%
df['Age'].value_counts().sort_index()
# Out:
# Age
# 18    12
# 19     8
# 20    13
# 21    14
# 22    17
# 23    12
# 24    16
# 25    12
# 26    12
# 27     9
# 28    15
# 29     6
# 30    11
# 31    14
# 32    15
# 33    18
# 34    17
# 35    15
# 36     7
# 37     8
# 38     9
# 39    11
# 40    10
# 41    10
# 42    10
# 43    10
# 44     8
# 45    16
# 46     7
# 47    12
# 48     6
# 49     8
# 50    12
# 51     8
# 52    18
# 53    15
# 54     9
# 55    12
# 56    13
# 57     5
# 58    12
# 59    12
# 60    16
# Name: count, dtype: int64

# %%
df['Age'].mean()
# Out:
# 38.45

# %%
print("Minimum Age:", df['Age'].min())
print("Maximum Age:", df['Age'].max())
# Out:
# Minimum Age: 18
# Maximum Age: 60

# %%
df['Age'].nunique()
# Out:
# 43

# %%
df['Age'].mode()
# Out:
# 0    33
# 1    52
# Name: Age, dtype: int64

# %%
age_counts = df['Age'].value_counts().sort_index()

plt.figure(figsize=(12,6))
age_counts.plot(kind='bar')
plt.title('Age Frequency Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.boxplot(df['Age'])
plt.title('Age Distribution Box Plot')
plt.ylabel('Age')
plt.show()

# %%
bins = [18,25,35,45,60]
labels = ['18-25','26-35','36-45','46-60']

df['Age_Group'] = pd.cut(df['Age'], bins=bins, labels=labels)

df['Age_Group'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.title('Age Group Distribution')
plt.show()

# %%
print("Total Records:", len(df))
print("Average Age:", round(df['Age'].mean(),2))
print("Median Age:", df['Age'].median())
print("Minimum Age:", df['Age'].min())
print("Maximum Age:", df['Age'].max())
# Out:
# Total Records: 500
# Average Age: 38.45
# Median Age: 37.0
# Minimum Age: 18
# Maximum Age: 60
